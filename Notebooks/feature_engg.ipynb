# %%
import pandas as pd

# %%
df = pd.read_csv('../data/powerdata.csv')
df.head(3)
# Out:
#     Timestamp  Voltage (V)  Current (A)  Power Consumption (kW)  \
# 0  2024-01-01   229.442065    23.274581                5.338170
# 1  2024-01-02   230.252406    27.590016                6.355897
# 2  2024-01-03   230.139098    26.616651                6.113400
#
#    Reactive Power (kVAR)  Power Factor  Solar Power (kW)  Wind Power (kW)  \
# 0               1.335934      0.904576         24.128362        15.614870
# 1               1.547024      0.902831         25.205873        13.585932
# 2               1.560915      0.898813         22.725012        14.149719
#
#    Grid Supply (kW)  Voltage Fluctuation (%)  Temperature (°C)  Humidity (%)  \
# 0          0.044420                -0.005502         24.458245     49.931362
# 1          0.042495                -0.336757         25.281132     47.592609
# 2          0.007981                -0.027104         25.286834     46.656764
#
#    Electricity Price (USD/kWh)  Predicted Load (kW)
# 0                     0.307196             5.341409
# 1                     0.300984             6.339775
# 2                     0.296841             6.096116

# %%
df.tail(3)
# Out:
#       Timestamp  Voltage (V)  Current (A)  Power Consumption (kW)  \
# 510  2025-05-25   230.833726    25.699244                5.929007
# 511  2025-05-26   230.123679    26.533685                6.112369
# 512  2025-05-27   230.239933    27.766174                6.388910
#
#      Reactive Power (kVAR)  Power Factor  Solar Power (kW)  Wind Power (kW)  \
# 510               1.373174      0.900475         25.763437        16.412181
# 511               1.552541      0.898765         25.205411        14.641372
# 512               1.613326      0.893845         25.686605        13.977853
#
#      Grid Supply (kW)  Voltage Fluctuation (%)  Temperature (°C)  \
# 510          0.000000                -0.540115         25.380000
# 511          0.048538                 0.193632         24.879234
# 512          0.019597                 0.189405         23.675152
#
#      Humidity (%)  Electricity Price (USD/kWh)  Predicted Load (kW)
# 510     49.391778                     0.308700             5.905941
# 511     50.752091                     0.298928             6.086054
# 512     52.512171                     0.299877             6.394222

# %%
#df_inference = pd.read_csv('../data/inferenceset.csv')
#df_inference.head(2)
# Out:
#     Timestamp  Voltage (V)  Current (A)  Power Consumption (kW)  \
# 0  2025-05-26   230.123679    26.533685                6.112369
# 1  2025-05-27   230.239933    27.766174                6.388910
#
#    Reactive Power (kVAR)  Power Factor  Solar Power (kW)  Wind Power (kW)  \
# 0               1.552541      0.898765         25.205411        14.641372
# 1               1.613326      0.893845         25.686605        13.977853
#
#    Grid Supply (kW)  Voltage Fluctuation (%)  Temperature (°C)  Humidity (%)  \
# 0          0.048538                 0.193632         24.879234     50.752091
# 1          0.019597                 0.189405         23.675152     52.512171
#
#    Electricity Price (USD/kWh)  Predicted Load (kW)  Overload Condition  \
# 0                     0.298928             6.086054                   0
# 1                     0.299877             6.394222                   0
#
#    Transformer Fault
# 0                  0
# 1                  0

# %%
df['load_da'] = df['Predicted Load (kW)'].shift(-1)
df['load_d2'] = df['Predicted Load (kW)'].shift(-2)

# %%
df.head(3)
# Out:
#     Timestamp  Voltage (V)  Current (A)  Power Consumption (kW)  \
# 0  2024-01-01   229.442065    23.274581                5.338170
# 1  2024-01-02   230.252406    27.590016                6.355897
# 2  2024-01-03   230.139098    26.616651                6.113400
#
#    Reactive Power (kVAR)  Power Factor  Solar Power (kW)  Wind Power (kW)  \
# 0               1.335934      0.904576         24.128362        15.614870
# 1               1.547024      0.902831         25.205873        13.585932
# 2               1.560915      0.898813         22.725012        14.149719
#
#    Grid Supply (kW)  Voltage Fluctuation (%)  Temperature (°C)  Humidity (%)  \
# 0          0.044420                -0.005502         24.458245     49.931362
# 1          0.042495                -0.336757         25.281132     47.592609
# 2          0.007981                -0.027104         25.286834     46.656764
#
#    Electricity Price (USD/kWh)  Predicted Load (kW)   load_da   load_d2
# 0                     0.307196             5.341409  6.339775  6.096116
# 1                     0.300984             6.339775  6.096116  6.495922
# 2                     0.296841             6.096116  6.495922  6.122499

# %%
df['lag_1'] = df['Predicted Load (kW)'].shift(1)
df['lag_2'] = df['Predicted Load (kW)'].shift(2)
df['lag_3'] = df['Predicted Load (kW)'].shift(3)
df.head(3)
# Out:
#     Timestamp  Voltage (V)  Current (A)  Power Consumption (kW)  \
# 0  2024-01-01   229.442065    23.274581                5.338170
# 1  2024-01-02   230.252406    27.590016                6.355897
# 2  2024-01-03   230.139098    26.616651                6.113400
#
#    Reactive Power (kVAR)  Power Factor  Solar Power (kW)  Wind Power (kW)  \
# 0               1.335934      0.904576         24.128362        15.614870
# 1               1.547024      0.902831         25.205873        13.585932
# 2               1.560915      0.898813         22.725012        14.149719
#
#    Grid Supply (kW)  Voltage Fluctuation (%)  Temperature (°C)  Humidity (%)  \
# 0          0.044420                -0.005502         24.458245     49.931362
# 1          0.042495                -0.336757         25.281132     47.592609
# 2          0.007981                -0.027104         25.286834     46.656764
#
#    Electricity Price (USD/kWh)  Predicted Load (kW)   load_da   load_d2  \
# 0                     0.307196             5.341409  6.339775  6.096116
# 1                     0.300984             6.339775  6.096116  6.495922
# 2                     0.296841             6.096116  6.495922  6.122499
#
#       lag_1     lag_2  lag_3
# 0       NaN       NaN    NaN
# 1  5.341409       NaN    NaN
# 2  6.339775  5.341409    NaN

# %%
df.shape
# Out:
# (513, 19)

# %%
df['pct_tmp_chg'] = df['Temperature (°C)'].pct_change()
df['pow_cons_chg'] = df['Power Consumption (kW)'].pct_change()
df['roll_mean_load3'] = df['Predicted Load (kW)'].rolling(3).mean()
df['roll_std_load3'] = df['Predicted Load (kW)'].rolling(3).std()

# %%
df.head(4)
# Out:
#     Timestamp  Voltage (V)  Current (A)  Power Consumption (kW)  \
# 0  2024-01-01   229.442065    23.274581                5.338170
# 1  2024-01-02   230.252406    27.590016                6.355897
# 2  2024-01-03   230.139098    26.616651                6.113400
# 3  2024-01-04   230.450687    28.109668                6.483036
#
#    Reactive Power (kVAR)  Power Factor  Solar Power (kW)  Wind Power (kW)  \
# 0               1.335934      0.904576         24.128362        15.614870
# 1               1.547024      0.902831         25.205873        13.585932
# 2               1.560915      0.898813         22.725012        14.149719
# 3               1.580661      0.905492         24.628754        16.369280
#
#    Grid Supply (kW)  Voltage Fluctuation (%)  ...  Predicted Load (kW)  \
# 0          0.044420                -0.005502  ...             5.341409
# 1          0.042495                -0.336757  ...             6.339775
# 2          0.007981                -0.027104  ...             6.096116
# 3          0.028228                -0.227224  ...             6.495922
#
#     load_da   load_d2     lag_1     lag_2     lag_3  pct_tmp_chg  \
# 0  6.339775  6.096116       NaN       NaN       NaN          NaN
# 1  6.096116  6.495922  5.341409       NaN       NaN     0.033645
# 2  6.495922  6.122499  6.339775  5.341409       NaN     0.000226
# 3  6.122499  5.881918  6.096116  6.339775  5.341409     0.029197
#
#    pow_cons_chg  roll_mean_load3  roll_std_load3
# 0           NaN              NaN             NaN
# 1      0.190651              NaN             NaN
# 2     -0.038153         5.925767        0.520527
# 3      0.060463         6.310604        0.201493
#
# [4 rows x 23 columns]

# %%
df.tail(4)
# Out:
#       Timestamp  Voltage (V)  Current (A)  Power Consumption (kW)  \
# 509  2025-05-24   229.562865    27.425332                6.303485
# 510  2025-05-25   230.833726    25.699244                5.929007
# 511  2025-05-26   230.123679    26.533685                6.112369
# 512  2025-05-27   230.239933    27.766174                6.388910
#
#      Reactive Power (kVAR)  Power Factor  Solar Power (kW)  Wind Power (kW)  \
# 509               1.572590      0.905289         25.302905        16.598401
# 510               1.373174      0.900475         25.763437        16.412181
# 511               1.552541      0.898765         25.205411        14.641372
# 512               1.613326      0.893845         25.686605        13.977853
#
#      Grid Supply (kW)  Voltage Fluctuation (%)  ...  Predicted Load (kW)  \
# 509          0.054278                 0.937430  ...             6.328458
# 510          0.000000                -0.540115  ...             5.905941
# 511          0.048538                 0.193632  ...             6.086054
# 512          0.019597                 0.189405  ...             6.394222
#
#       load_da   load_d2     lag_1     lag_2     lag_3  pct_tmp_chg  \
# 509  5.905941  6.086054  6.661790  6.425520  5.861519     0.056038
# 510  6.086054  6.394222  6.328458  6.661790  6.425520    -0.035704
# 511  6.394222       NaN  5.905941  6.328458  6.661790    -0.019731
# 512       NaN       NaN  6.086054  5.905941  6.328458    -0.048397
#
#      pow_cons_chg  roll_mean_load3  roll_std_load3
# 509     -0.059703         6.471923        0.171442
# 510     -0.059408         6.298729        0.378801
# 511      0.030926         6.106817        0.212022
# 512      0.045243         6.128739        0.246923
#
# [4 rows x 23 columns]

# %%
df.dropna(inplace=True)
df.isna().sum()
# Out:
# Timestamp                      0
# Voltage (V)                    0
# Current (A)                    0
# Power Consumption (kW)         0
# Reactive Power (kVAR)          0
# Power Factor                   0
# Solar Power (kW)               0
# Wind Power (kW)                0
# Grid Supply (kW)               0
# Voltage Fluctuation (%)        0
# Temperature (°C)               0
# Humidity (%)                   0
# Electricity Price (USD/kWh)    0
# Predicted Load (kW)            0
# load_da                        0
# load_d2                        0
# lag_1                          0
# lag_2                          0
# lag_3                          0
# pct_tmp_chg                    0
# pow_cons_chg                   0
# roll_mean_load3                0
# roll_std_load3                 0
# dtype: int64

# %%
df.to_csv('../data/feature_engineered.csv')
